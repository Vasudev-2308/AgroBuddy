# %%
from google.colab import files

# %%
import numpy as np
import pandas as pd
import os 


len(os.listdir("/content/drive/MyDrive/PlantDisease/Dataset/train"))
# Out:
# 38

# %%
import keras 

from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions

# %%
train_datagen = ImageDataGenerator(zoom_range=0.5, shear_range=0.3, horizontal_flip=True, preprocessing_function=preprocess_input)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train = train_datagen.flow_from_directory(directory="/content/drive/MyDrive/PlantDisease/Dataset/train", target_size=(256,256), batch_size=32)


valid = val_datagen.flow_from_directory("/content/drive/MyDrive/PlantDisease/Dataset/valid", target_size=(256,256), batch_size=32)
# Out:
# Found 70363 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.

# %%
from keras.layers import Dense, Flatten
from keras.models import Model

# %%
#Base Model

base_model = VGG19(input_shape=(256,256,3), include_top=False)

base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
x = Flatten()(base_model.output)

x = Dense(units=38, activation='softmax')(x)

model = Model(base_model.input, x)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 38)                1245222
#
# =================================================================
# Total params: 21,269,606
# Trainable params: 1,245,222
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Early Stopping and Callbacks 


from keras.callbacks import ModelCheckpoint, EarlyStopping

earlyStopping = EarlyStopping(monitor='val_loss', min_delta=0.01,patience=3, verbose=1)

#model Checkpoint 

modelCheckpoint = ModelCheckpoint("model_best.h5", save_best_only=True,monitor='val_accuracy', verbose=1)


callback = [earlyStopping, modelCheckpoint]

# %%
model.compile(optimizer='adam', loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
history = model.fit_generator(
    train, 
    steps_per_epoch=15, 
    epochs=50, 
    callbacks=callback, 
    validation_data=valid, verbose=1, validation_steps=15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/50
# 15/15 [==============================] - ETA: 0s - loss: 26.8460 - accuracy: 0.1646
# Epoch 1: val_accuracy improved from -inf to 0.36042, saving model to model_best.h5
# 15/15 [==============================] - 220s 14s/step - loss: 26.8460 - accuracy: 0.1646 - val_loss: 16.0878 - val_accuracy: 0.3604
# Epoch 2/50
# 15/15 [==============================] - ETA: 0s - loss: 15.2487 - accuracy: 0.4083
# Epoch 2: val_accuracy improved from 0.36042 to 0.58958, saving model to model_best.h5
# 15/15 [==============================] - 206s 14s/step - loss: 15.2487 - accuracy: 0.4083 - val_loss: 8.3348 - val_accuracy: 0.5896
# Epoch 3/50
# 15/15 [==============================] - ETA: 0s - loss: 10.7434 - accuracy: 0.5333
# Epoch 3: val_accuracy improved from 0.58958 to 0.67917, saving model to model_best.h5
# 15/15 [==============================] - 207s 14s/step - loss: 10.7434 - accuracy: 0.5333 - val_loss: 7.5730 - val_accuracy: 0.6792
# Epoch 4/50
# 15/15 [==============================] - ETA: 0s - loss: 10.7830 - accuracy: 0.5625
# Epoch 4: val_accuracy improved from 0.67917 to 0.68958, saving model to model_best.h5
# 15/15 [==============================] - 203s 14s/step - loss: 10.7830 - accuracy: 0.5625 - val_loss: 6.9831 - val_accuracy: 0.6896
# Epoch 5/50
# 15/15 [==============================] - ETA: 0s - loss: 9.1520 - accuracy: 0.6104
# Epoch 5: val_accuracy improved from 0.68958 to 0.70417, saving model to model_best.h5
# 15/15 [==============================] - 198s 14s/step - loss: 9.1520 - accuracy: 0.6104 - val_loss: 7.8756 - val_accuracy: 0.7042
# Epoch 6/50
# 15/15 [==============================] - ETA: 0s - loss: 9.8922 - accuracy: 0.6125
# Epoch 6: val_accuracy improved from 0.70417 to 0.75000, saving model to model_best.h5
# 15/15 [==============================] - 193s 13s/step - loss: 9.8922 - accuracy: 0.6125 - val_loss: 6.5695 - val_accuracy: 0.7500
# Epoch 7/50
# 15/15 [==============================] - ETA: 0s - loss: 9.2999 - accuracy: 0.6562
# Epoch 7: val_accuracy did not improve from 0.75000
# 15/15 [==============================] - 189s 13s/step - loss: 9.2999 - accuracy: 0.6562 - val_loss: 8.3662 - val_accuracy: 0.6958
# Epoch 8/50
# 15/15 [==============================] - ETA: 0s - loss: 9.1565 - accuracy: 0.6375
# Epoch 8: val_accuracy improved from 0.75000 to 0.77292, saving model to model_best.h5
# 15/15 [==============================] - 191s 13s/step - loss: 9.1565 - accuracy: 0.6375 - val_loss: 6.0709 - val_accuracy: 0.7729
# Epoch 9/50
# 15/15 [==============================] - ETA: 0s - loss: 9.7091 - accuracy: 0.6500
# Epoch 9: val_accuracy improved from 0.77292 to 0.81042, saving model to model_best.h5
# 15/15 [==============================] - 186s 13s/step - loss: 9.7091 - accuracy: 0.6500 - val_loss: 5.6645 - val_accuracy: 0.8104
# Epoch 10/50
# 15/15 [==============================] - ETA: 0s - loss: 9.2713 - accuracy: 0.6729
# Epoch 10: val_accuracy did not improve from 0.81042
# 15/15 [==============================] - 178s 12s/step - loss: 9.2713 - accuracy: 0.6729 - val_loss: 6.6245 - val_accuracy: 0.7646
# Epoch 11/50
# 15/15 [==============================] - ETA: 0s - loss: 8.4250 - accuracy: 0.7188
# Epoch 11: val_accuracy did not improve from 0.81042
# 15/15 [==============================] - 180s 12s/step - loss: 8.4250 - accuracy: 0.7188 - val_loss: 7.9003 - val_accuracy: 0.7708
# Epoch 12/50
# 15/15 [==============================] - ETA: 0s - loss: 7.7932 - accuracy: 0.7125
# Epoch 12: val_accuracy improved from 0.81042 to 0.83333, saving model to model_best.h5
# 15/15 [==============================] - 178s 12s/step - loss: 7.7932 - accuracy: 0.7125 - val_loss: 4.7186 - val_accuracy: 0.8333
# Epoch 13/50
# 15/15 [==============================] - ETA: 0s - loss: 8.2900 - accuracy: 0.7333
# Epoch 13: val_accuracy did not improve from 0.83333
# 15/15 [==============================] - 174s 12s/step - loss: 8.2900 - accuracy: 0.7333 - val_loss: 6.7494 - val_accuracy: 0.8021
# Epoch 14/50
# 15/15 [==============================] - ETA: 0s - loss: 7.6662 - accuracy: 0.7167
# Epoch 14: val_accuracy did not improve from 0.83333
# 15/15 [==============================] - 162s 11s/step - loss: 7.6662 - accuracy: 0.7167 - val_loss: 6.4298 - val_accuracy: 0.8083
# Epoch 15/50
# 15/15 [==============================] - ETA: 0s - loss: 7.1107 - accuracy: 0.7625
# Epoch 15: val_accuracy did not improve from 0.83333
# 15/15 [==============================] - 166s 11s/step - loss: 7.1107 - accuracy: 0.7625 - val_loss: 5.2505 - val_accuracy: 0.8188
# Epoch 15: early stopping

# %%
import matplotlib.pyplot as plt

h = history.history

plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'], c='red')
plt.title('acc vs val_acc')

plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'], c='red')
plt.title('loss vs val_loss')

plt.show()

# %%
#load best model 

from keras.models import load_model

trained_model = load_model("/content/model_best.h5")

# %%
disease_ref = dict(zip(list(train.class_indices.values()), list(train.class_indices.keys())))

# %%
def prediction(path):
  img = load_img(path, target_size=(256,256))
  i = img_to_array(img)
  im = preprocess_input(i)
  img = np.expand_dims(im, axis=0)

  pred = np.argmax(trained_model.predict(img))

  return (pred)

# %%
disease_index = prediction("/content/drive/MyDrive/PlantDisease/test/test/AppleScab2.JPG")

print(disease_ref[disease_index])
# Out:
# Apple___Apple_scab

# %%
import pickle

# %%
with open('plant_disease_detection_model.pkl', 'wb') as file_:
    pickle.dump(trained_model, file_)
# Out:
# INFO:tensorflow:Assets written to: ram://1a44430c-3dba-4f2c-9890-31f5570ec0a9/assets
